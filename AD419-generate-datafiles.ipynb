# %% [markdown]
# ## Program for AD419 Project and Cateogry Totals
#
# Define categories for our departments, and then break up the totals in two different ways:
#
# 1. By project, using overall totals
# 2. By category, for each source

# %%
import pandas as pd
import numpy as np

# %%
departments = {
    'ARE': {
        'name': 'Agricultural & Resource Economics',
        'category': 'HUMAN'
    },
    'BAE': {
        'name': 'Biological & Agricultural Engineering',
        'category': 'AG'
    },
    'PLS': {
        'name': 'Plant Sciences',
        'category': 'AG'
    },
    'PLB': {
        'name': 'Plant Biology',
        'category': 'BIO'
    },
    'PPA': {
        'name': 'Plant Pathology',
        'category': 'AG'
    },
    'ASC': {
        'name': 'Animal Science',
        'category': 'AG'
    },
    'HCE': {
        'name': 'Human Ecology',
        'category': 'HUMAN'
    },
    'TXC': {
        'name': 'Textiles & Clothing',
        'category': 'HUMAN'
    },
    'ESP': {
        'name': 'Environmental Science & Policy',
        'category': 'ENV'
    },
    'ENM': {
        'name': 'Entomology & Nematology',
        'category': 'AG'
    },
    'ETX': {
        'name': 'Environmental Toxicology',
        'category': 'ENV'
    },
    'LAW': {
        'name': 'Land, Air & Water Resources',
        'category': 'ENV'
    },
    'WFB': {
        'name': 'Wildlife, Fish & Conservation Biology',
        'category': 'ENV'
    },
    'VIT': {
        'name': 'Viticulture & Enology',
        'category': 'AG'
    },
    'FST': {
        'name': 'Food Science & Technology',
        'category': 'HUMAN'
    },
    'NTR': {
        'name': 'Nutrition',
        'category': 'HUMAN'
    },
    'MCB': {
        'name': 'Molecular & Cellular Biology',
        'category': 'BIO'
    },
    'EVE': {
        'name': 'Evolution & Ecology',
        'category': 'BIO'
    },
    'MIC': {
        'name': 'Microbiology & Molecular Genetics',
        'category': 'BIO'
    },
    'NPB': {
        'name': 'Neurobiology, Physiology & Behavior',
        'category': 'BIO'
    },
}

# %%
# read in the whole CSV
df = pd.read_csv('./ad419admin.csv', thousands=',')
df.head()
# Out:
#   loc dept  proj           project  accession                PI     f201  \
# 0  D   ARE  2027   CA-D-ARE-2027-H    1004905  Goodhue, Rachael      0.0
# 1  D   ARE  2186  CA-D-ARE-2186-RR     232974      Hardesty,  S      0.0
# 2  D   ARE  2194   CA-D-ARE-2194-H    1002098         Paris,  Q      0.0
# 3  D   ARE  2197  CA-D-ARE-2197-H     1001956        Taylor,  J  47119.0
# 4  D   ARE  2198   CA-D-ARE-2198-H    1001957      Novan, Kevin      0.0
#
#    f202  f203  f204    ...        Textbox64    Textbox65    Textbox66  \
# 0   0.0   0.0   0.0    ...      12248471.88  23963343.51  17942419.49
# 1   0.0   0.0   0.0    ...      12248471.88  23963343.51  17942419.49
# 2   0.0   0.0   0.0    ...      12248471.88  23963343.51  17942419.49
# 3   0.0   0.0   0.0    ...      12248471.88  23963343.51  17942419.49
# 4   0.0   0.0   0.0    ...      12248471.88  23963343.51  17942419.49
#
#       Textbox67     Textbox68  Textbox69  Textbox70  Textbox71  Textbox72  \
# 0  1.254189e+08  2.020218e+08      230.4      691.7      155.0      260.2
# 1  1.254189e+08  2.020218e+08      230.4      691.7      155.0      260.2
# 2  1.254189e+08  2.020218e+08      230.4      691.7      155.0      260.2
# 3  1.254189e+08  2.020218e+08      230.4      691.7      155.0      260.2
# 4  1.254189e+08  2.020218e+08      230.4      691.7      155.0      260.2
#
#    Textbox73
# 0     1337.3
# 1     1337.3
# 2     1337.3
# 3     1337.3
# 4     1337.3
#
# [5 rows x 66 columns]

# %%
# clean up Textbox columns
for c in df.columns:
    if c.startswith("Textbox"):
        del df[c]
        
# delete other cols we aren't using
del df['accession']
del df['proj']
# f241-244 + 350 are FTE columns we don't want
del df['f241']
del df['f242']
del df['f243']
del df['f244']
del df['f350']

# remove IND and Cross dept rows
df = df.query("dept != 'IND' & dept != 'XXX'")

# grab the removed just to see what they are
df_removed = df.query("dept == 'IND' | dept == 'XXX'")

# %%
df.head()

# df_removed['f234'].sum()
# Out:
#   loc dept           project                PI     f201  f202  f203  f204  \
# 0  D   ARE   CA-D-ARE-2027-H  Goodhue, Rachael      0.0   0.0   0.0   0.0
# 1  D   ARE  CA-D-ARE-2186-RR      Hardesty,  S      0.0   0.0   0.0   0.0
# 2  D   ARE   CA-D-ARE-2194-H         Paris,  Q      0.0   0.0   0.0   0.0
# 3  D   ARE  CA-D-ARE-2197-H         Taylor,  J  47119.0   0.0   0.0   0.0
# 4  D   ARE   CA-D-ARE-2198-H      Novan, Kevin      0.0   0.0   0.0   0.0
#
#    f205     f231    ...      f315  f318      f332       f220  f22F     f221  \
# 0   0.0      0.0    ...       0.0   0.0  16368.35  310492.61   0.0  1515.32
# 1   0.0      0.0    ...       0.0   0.0  67744.42   82019.75   0.0  8765.78
# 2   0.0      0.0    ...       0.0   0.0   2895.00   42344.62   0.0  1515.32
# 3   0.0  47119.0    ...       0.0   0.0  13074.32  152843.08   0.0  1515.32
# 4   0.0      0.0    ...       0.0   0.0   2895.00  125043.68   0.0  1515.32
#
#        f222      f223       f233       f234
# 0  22138.47  11042.33  345188.73  361557.08
# 1  22138.47  15561.27  128485.27  196229.69
# 2  22138.47  14359.27   80357.68   83252.68
# 3  22138.47  63603.33  240100.20  300293.52
# 4  22138.47  14359.27  163056.74  165951.74
#
# [5 rows x 29 columns]

# %%
# build the default nodes (TODO: populate from df)
data = []

for index, row in df.iterrows():
    data.append({
        'project': row['project'],
        'dept': row['dept'],
        'total': row['f234']
    })

# %%
# remove all 0 totals project

data = [x for x in data if x['total'] > 0]

data
# Out:
# [{'dept': 'ARE', 'project': 'CA-D-ARE-2027-H', 'total': 361557.08},
#  {'dept': 'ARE', 'project': 'CA-D-ARE-2186-RR', 'total': 196229.69},
#  {'dept': 'ARE', 'project': 'CA-D-ARE-2194-H', 'total': 83252.68},
#  {'dept': 'ARE', 'project': 'CA-D-ARE-2197-H ', 'total': 300293.52},
#  {'dept': 'ARE', 'project': 'CA-D-ARE-2198-H', 'total': 165951.74},
#  {'dept': 'ARE', 'project': 'CA-D-ARE-2199-H', 'total': 179449.44},
#  {'dept': 'ARE', 'project': 'CA-D-ARE-2200-H', 'total': 428557.85},
#  {'dept': 'ARE', 'project': 'CA-D-ARE-2215-H', 'total': 128428.73},
#  {'dept': 'ARE', 'project': 'CA-D-ARE-2249-H', 'total': 165148.92},
#  {'dept': 'ARE', 'project': 'CA-D-ARE-2251-H', 'total': 201054.45},
#  {'dept': 'ARE', 'project': 'CA-D-ARE-2254-H', 'total': 401403.14},
#  {'dept': 'ARE', 'project': 'CA-D-ARE-2280-H', 'total': 259799.48},
#  {'dept': 'ARE', 'project': 'CA-D-ARE-2294-H', 'total': 234828.84},
#  {'dept': 'ARE', 'project': 'CA-D-ARE-2298-H', 'total': 233247.7},
#  {'dept': 'ARE', 'project': 'CA-D-ARE-2331-CG', 'total': 259799.48},
#  {'dept': 'ARE', 'project': 'CA-D-ARE-2363-H', 'total': 213976.35},
#  {'dept': 'ARE', 'project': 'CA-D-ARE-2364-H', 'total': 5564755.32},
#  {'dept': 'ARE', 'project': 'CA-D-ARE-6585-H', 'total': 220922.98},
#  {'dept': 'ARE', 'project': 'CA-D-ARE-6987-H', 'total': 316291.61},
#  {'dept': 'ARE', 'project': 'CA-D-ARE-7307-RR', 'total': 192554.48},
#  {'dept': 'ARE', 'project': 'CA-D-ARE-7639-RR', 'total': 413522.52},
#  {'dept': 'ARE', 'project': 'CA-D-ARE-7733-H', 'total': 324636.88},
#  {'dept': 'ARE', 'project': 'CA-D-ARE-7740-H', 'total': 83336.57},
#  {'dept': 'ARE', 'project': 'CA-D-ARE-7820-H', 'total': 331263.77},
#  {'dept': 'ARE', 'project': 'CA-D-ARE-7833-H', 'total': 241197.36},
#  {'dept': 'ARE', 'project': 'CA-D-ARE-7837-H', 'total': 162547.02},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2002-RR', 'total': 188418.72},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2003-RR', 'total': 303004.67},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2024-RR', 'total': 302371.78},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2070-RR', 'total': 253198.55},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2095-RR', 'total': 331420.83},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2138-RR', 'total': 239120.97},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2155-RR', 'total': 213536.68},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2156-RR', 'total': 213536.68},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2157-RR', 'total': 213536.68},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2193-RR', 'total': 1390611.07},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2209-RR', 'total': 208817.97},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2237-OG', 'total': 289210.68},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2239-RR', 'total': 213536.68},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2240-RR', 'total': 213536.68},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2250-AH', 'total': 792457.46},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2252-H', 'total': 267061.26},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2253-RR', 'total': 267061.26},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2262-RR', 'total': 210837.55},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2263-H', 'total': 95023.38},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2283-CG ', 'total': 252335.32},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2286-H', 'total': 93409.15},
#  {'dept': 'ASC', 'project': 'CA-D-ANS-2299-CG', 'total': 234938.72},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2303-RR', 'total': 159873.21},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2304-RR', 'total': 233512.13},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2306-RR', 'total': 136130.21},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2307-RR', 'total': 233517.06},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2308-CG', 'total': 350727.67},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2339-RR', 'total': 407463.24},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2341-RR', 'total': 119550.89},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2342-RR', 'total': 119550.89},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2355-RR', 'total': 194546.67},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2356-RR', 'total': 194546.67},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2360-H', 'total': 254042.66},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2371-RR', 'total': 235033.55},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2372-CG', 'total': 221185.13},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2374-OG', 'total': 143000.08},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2380-CG', 'total': 237105.33},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2389-RR', 'total': 244447.84},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2390-RR', 'total': 244447.84},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2414-CG', 'total': 207229.47},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-2420-CG', 'total': 305259.92},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-5929-RR ', 'total': 413242.26},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-6414-RR', 'total': 165487.84},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-6578-H', 'total': 426204.83},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-6796-RR', 'total': 253764.09},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-7233-RR', 'total': 230352.84},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-7281-RR', 'total': 165509.34},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-7366-RR', 'total': 372423.25},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-7369-RR', 'total': 409668.51},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-7373-RR', 'total': 207229.47},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-7384-RR', 'total': 207253.84},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-7507-H', 'total': 181815.06},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-7624-RR', 'total': 260364.29},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-7666-RR', 'total': 239120.97},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-7690-H', 'total': 309959.29},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-7744-RR', 'total': 459552.32},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-7771-RR', 'total': 155907.82},
#  {'dept': 'ASC', 'project': 'CA-D-ASC-7776-RR', 'total': 155907.82},
#  {'dept': 'BAE', 'project': 'CA-D-BAE-2005-RR', 'total': 772177.02},
#  {'dept': 'BAE', 'project': 'CA-D-BAE-2011-RR', 'total': 131459.69},
#  {'dept': 'BAE', 'project': 'CA-D-BAE-2031-H', 'total': 343550.44},
#  {'dept': 'BAE', 'project': 'CA-D-BAE-2190-RR', 'total': 147242.14},
#  {'dept': 'BAE', 'project': 'CA-D-BAE-2208-CG', 'total': 384729.14},
#  {'dept': 'BAE', 'project': 'CA-D-BAE-2212-H', 'total': 126322.62},
#  {'dept': 'BAE', 'project': 'CA-D-BAE-2225-CG', 'total': 379209.44},
#  {'dept': 'BAE', 'project': 'CA-D-BAE-2228-RR', 'total': 494349.61},
#  {'dept': 'BAE', 'project': 'CA-D-BAE-2230-RR', 'total': 168204.62},
#  {'dept': 'BAE', 'project': 'CA-D-BAE-2231-RR', 'total': 273539.31},
#  {'dept': 'BAE', 'project': 'CA-D-BAE-2270-OG', 'total': 807219.17},
#  {'dept': 'BAE', 'project': 'CA-D-BAE-2271-OG', 'total': 350897.4},
#  {'dept': 'BAE', 'project': 'CA-D-BAE-2277-RR', 'total': 326144.68},
#  {'dept': 'BAE', 'project': 'CA-D-BAE-2312-OG', 'total': 185035.14},
#  {'dept': 'BAE', 'project': 'CA-D-BAE-2314-CG', 'total': 494513.14},
#  {'dept': 'BAE', 'project': 'CA-D-BAE-2335-RR', 'total': 290519.37},
#  {'dept': 'BAE', 'project': 'CA-D-BAE-2375-OG', 'total': 454236.79},
#  {'dept': 'BAE', 'project': 'CA-D-BAE-6444-H', 'total': 137904.4},
#  {'dept': 'BAE', 'project': 'CA-D-BAE-7098-H', 'total': 473636.21},
#  {'dept': 'BAE', 'project': 'CA-D-BAE-7099-H', 'total': 506104.65},
#  {'dept': 'BAE', 'project': 'CA-D-BAE-7725-H', 'total': 131459.69},
#  {'dept': 'BAE', 'project': 'CA-D-BAE-7737-RR', 'total': 772177.02},
#  {'dept': 'BAE', 'project': 'CA-D-BAE-7746-H', 'total': 218791.31},
#  {'dept': 'BAE', 'project': 'CA-D-BAE-7808-RR', 'total': 247844.17},
#  {'dept': 'ENM', 'project': 'CA-D-ENM-2064-H', 'total': 379998.73},
#  {'dept': 'ENM', 'project': 'CA-D-ENM-2103-H', 'total': 328209.58},
#  {'dept': 'ENM', 'project': 'CA-D-ENM-2105-H', 'total': 1149456.8},
#  {'dept': 'ENM', 'project': 'CA-D-ENM-2141-H', 'total': 590095.02},
#  {'dept': 'ENM', 'project': 'CA-D-ENM-2150-H', 'total': 1087890.3},
#  {'dept': 'ENM', 'project': 'CA-D-ENM-2161-H', 'total': 350081.7},
#  {'dept': 'ENM', 'project': 'CA-D-ENM-2174-OG', 'total': 948073.55},
#  {'dept': 'ENM', 'project': 'CA-D-ENM-2189-RR', 'total': 241036.21},
#  {'dept': 'ENM', 'project': 'CA-D-ENM-2309-H', 'total': 687052.9},
#  {'dept': 'ENM', 'project': 'CA-D-ENM-2316-OG', 'total': 338407.37},
#  {'dept': 'ENM', 'project': 'CA-D-ENM-2351-H', 'total': 240438.55},
#  {'dept': 'ENM', 'project': 'CA-D-ENM-2353-RR', 'total': 251034.16},
#  {'dept': 'ENM', 'project': 'CA-D-ENM-2354-RR', 'total': 240438.55},
#  {'dept': 'ENM', 'project': 'CA-D-ENM-4162-H', 'total': 397657.7},
#  {'dept': 'ENM', 'project': 'CA-D-ENM-4278-H', 'total': 251034.16},
#  {'dept': 'ENM', 'project': 'CA-D-ENM-5234-H', 'total': 380991.29},
#  {'dept': 'ENM', 'project': 'CA-D-ENM-5671-RR', 'total': 290725.37},
#  {'dept': 'ENM', 'project': 'CA-D-ENM-6020-H', 'total': 328263.55},
#  {'dept': 'ENM', 'project': 'CA-D-ENM-6264-H', 'total': 857282.53},
#  {'dept': 'ENM', 'project': 'CA-D-ENM-6546-H', 'total': 362861.66},
#  {'dept': 'ENM', 'project': 'CA-D-ENM-6772-H', 'total': 444325.29},
#  {'dept': 'ENM', 'project': 'CA-D-ENM-6851-H', 'total': 545983.16},
#  {'dept': 'ENM', 'project': 'CA-D-ENM-7136-H', 'total': 304914.31},
#  {'dept': 'ENM', 'project': 'CA-D-ENM-7314-RR', 'total': 251046.42},
#  {'dept': 'ENM', 'project': 'CA-D-ENM-7356-RR', 'total': 260966.39},
#  {'dept': 'ENM', 'project': 'CA-D-ENM-7654-H', 'total': 2298344.34},
#  {'dept': 'ESP', 'project': 'CA-D-ESP-2020-H', 'total': 374374.01},
#  {'dept': 'ESP', 'project': 'CA-D-ESP-2084-H', 'total': 255647.14},
#  {'dept': 'ESP', 'project': 'CA-D-ESP-2086-H', 'total': 261191.0},
#  {'dept': 'ESP', 'project': 'CA-D-ESP-2087-H', 'total': 292331.16},
#  {'dept': 'ESP', 'project': 'CA-D-ESP-2094-H', 'total': 283711.1},
#  {'dept': 'ESP', 'project': 'CA-D-ESP-2163-H', 'total': 616384.65},
#  {'dept': 'ESP', 'project': 'CA-D-ESP-2201-H ', 'total': 437142.14},
#  {'dept': 'ESP', 'project': 'CA-D-ESP-2244-H', 'total': 286215.04},
#  {'dept': 'ESP', 'project': 'CA-D-ESP-2245-H', 'total': 487499.52},
#  {'dept': 'ESP', 'project': 'CA-D-ESP-2367-OG', 'total': 294730.47},
#  {'dept': 'ESP', 'project': 'CA-D-ESP-7005-H', 'total': 298908.09},
#  {'dept': 'ESP', 'project': 'CA-D-ESP-7104-H', 'total': 687292.66},
#  {'dept': 'ESP', 'project': 'CA-D-ESP-7122-H', 'total': 475685.48},
#  {'dept': 'ESP', 'project': 'CA-D-ESP-7140-H', 'total': 247903.28},
#  {'dept': 'ESP', 'project': 'CA-D-ESP-7687-H', 'total': 304065.0},
#  {'dept': 'ESP', 'project': 'CA-D-ESP-7853-H', 'total': 487792.66},
#  {'dept': 'ETX', 'project': 'CA-D-ETX-2102-H', 'total': 274050.9},
#  {'dept': 'ETX', 'project': 'CA-D-ETX-2152-H', 'total': 272571.99},
#  {'dept': 'ETX', 'project': 'CA-D-ETX-2227-H', 'total': 502575.98},
#  {'dept': 'ETX', 'project': 'CA-D-ETX-2233-H', 'total': 779976.79},
#  {'dept': 'ETX', 'project': 'CA-D-ETX-2293-SG', 'total': 2051898.26},
#  {'dept': 'ETX', 'project': 'CA-D-ETX-2345-H', 'total': 119363.97},
#  {'dept': 'ETX', 'project': 'CA-D-ETX-2421-CG', 'total': 123560.31},
#  {'dept': 'ETX', 'project': 'CA-D-ETX-3926-H', 'total': 298066.86},
#  {'dept': 'ETX', 'project': 'CA-D-ETX-6718-H', 'total': 1524797.18},
#  {'dept': 'ETX', 'project': 'CA-D-ETX-7751-RR', 'total': 369194.77},
#  {'dept': 'EVE', 'project': 'CA-D-EVE-2241-H', 'total': 680414.28},
#  {'dept': 'EVE', 'project': 'CA-D-EVE-2264-H', 'total': 97445.44},
#  {'dept': 'EVE', 'project': 'CA-D-EVE-2265-H', 'total': 100074.84},
#  {'dept': 'EVE', 'project': 'CA-D-EVE-2266-H', 'total': 330519.7},
#  {'dept': 'EVE', 'project': 'CA-D-EVE-2268-H', 'total': 292202.61},
#  {'dept': 'EVE', 'project': 'CA-D-EVE-2365-H', 'total': 126972.56},
#  {'dept': 'EVE', 'project': 'CA-D-EVE-2369-H', 'total': 145245.98},
#  {'dept': 'EVE', 'project': 'CA-D-EVE-3515-H', 'total': 326650.95},
#  {'dept': 'EVE', 'project': 'CA-D-EVE-4244-H', 'total': 388918.68},
#  {'dept': 'EVE', 'project': 'CA-D-EVE-5490-H', 'total': 131629.89},
#  {'dept': 'EVE', 'project': 'CA-D-EVE-5542-H', 'total': 463108.7},
#  {'dept': 'EVE', 'project': 'CA-D-EVE-5630-H', 'total': 100296.98},
#  {'dept': 'EVE', 'project': 'CA-D-EVE-6882-H', 'total': 402711.29},
#  {'dept': 'EVE', 'project': 'CA-D-EVE-7118-H', 'total': 98666.24},
#  {'dept': 'FST', 'project': 'CA-D-FST-2028-H', 'total': 634302.89},
#  {'dept': 'FST', 'project': 'CA-D-FST-2090-H', 'total': 213773.12},
#  {'dept': 'FST', 'project': 'CA-D-FST-2093-H', 'total': 272696.9},
#  {'dept': 'FST', 'project': 'CA-D-FST-2106-H', 'total': 310820.36},
#  {'dept': 'FST', 'project': 'CA-D-FST-2187-H', 'total': 724638.17},
#  {'dept': 'FST', 'project': 'CA-D-FST-2236-RR', 'total': 336256.43},
#  {'dept': 'FST', 'project': 'CA-D-FST-2281-CG', 'total': 365911.21},
#  {'dept': 'FST', 'project': 'CA-D-FST-2282-CG', 'total': 1066127.12},
#  {'dept': 'FST', 'project': 'CA-D-FST-2317-H', 'total': 338377.88},
#  {'dept': 'FST', 'project': 'CA-D-FST-2321-OG', 'total': 281849.88},
#  {'dept': 'FST', 'project': 'CA-D-FST-2348-RR', 'total': 361322.3},
#  {'dept': 'FST', 'project': 'CA-D-FST-2366-OG', 'total': 196744.81},
#  {'dept': 'FST', 'project': 'CA-D-FST-2377-OG', 'total': 307852.33},
#  {'dept': 'FST', 'project': 'CA-D-FST-2379-RR', 'total': 195483.28},
#  {'dept': 'FST', 'project': 'CA-D-FST-3627-H', 'total': 161874.07},
#  {'dept': 'FST', 'project': 'CA-D-FST-4929-H', 'total': 646461.14},
#  {'dept': 'FST', 'project': 'CA-D-FST-6097-H', 'total': 351427.94},
#  {'dept': 'FST', 'project': 'CA-D-FST-6568-H', 'total': 1701786.13},
#  {'dept': 'FST', 'project': 'CA-D-FST-6975-H', 'total': 361344.27},
#  {'dept': 'FST', 'project': 'CA-D-FST-7105-H', 'total': 306905.72},
#  {'dept': 'FST', 'project': 'CA-D-FST-7598-H ', 'total': 666620.18},
#  {'dept': 'HCE', 'project': 'CA-D-HCE-2049-H', 'total': 192082.12},
#  {'dept': 'HCE', 'project': 'CA-D-HCE-2050-H', 'total': 487326.13},
#  {'dept': 'HCE', 'project': 'CA-D-HCE-2051-H', 'total': 146368.92},
#  {'dept': 'HCE', 'project': 'CA-D-HCE-2055-H', 'total': 126682.12},
#  {'dept': 'HCE', 'project': 'CA-D-HCE-2151-H', 'total': 202138.32},
#  {'dept': 'HCE', 'project': 'CA-D-HCE-2159-RR', 'total': 146368.92},
#  {'dept': 'HCE', 'project': 'CA-D-HCE-2184-RR', 'total': 147234.26},
#  {'dept': 'HCE', 'project': 'CA-D-HCE-2195-H', 'total': 103843.31},
#  {'dept': 'HCE', 'project': 'CA-D-HCE-2213-H', 'total': 89907.86},
#  {'dept': 'HCE', 'project': 'CA-D-HCE-2214-H', 'total': 143448.41},
#  {'dept': 'HCE', 'project': 'CA-D-HCE-2220-H', 'total': 98823.99},
#  {'dept': 'HCE', 'project': 'CA-D-HCE-2234-H', 'total': 84481.5},
#  {'dept': 'HCE', 'project': 'CA-D-HCE-2267-H', 'total': 255500.08},
#  {'dept': 'HCE', 'project': 'CA-D-HCE-2269-H', 'total': 171985.46},
#  {'dept': 'HCE', 'project': 'CA-D-HCE-2300-H', 'total': 158067.23},
#  {'dept': 'HCE', 'project': 'CA-D-HCE-2302-H ', 'total': 110958.15},
#  {'dept': 'HCE', 'project': 'CA-D-HCE-2319-H', 'total': 151096.51},
#  {'dept': 'HCE', 'project': 'CA-D-HCE-2344-RR', 'total': 120584.91},
#  {'dept': 'HCE', 'project': 'CA-D-HCE-2358-H', 'total': 123525.33},
#  {'dept': 'HCE', 'project': 'CA-D-HCE-2361-H', 'total': 145888.01},
#  {'dept': 'HCE', 'project': 'CA-D-HCE-2362-H', 'total': 257664.0},
#  {'dept': 'HCE', 'project': 'CA-D-HCE-7035-H', 'total': 104897.03},
#  {'dept': 'HCE', 'project': 'CA-D-HCE-7513-H', 'total': 381187.65},
#  {'dept': 'HCE', 'project': 'CA-D-HCE-7743-H', 'total': 151215.15},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-2058-H', 'total': 145099.81},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-2076-H', 'total': 122358.14},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-2085-H', 'total': 125208.25},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-2122-H', 'total': 303198.32},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-2128-CG', 'total': 429360.92},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-2177-OG', 'total': 250297.92},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-2178-H', 'total': 414251.68},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-2203-H', 'total': 847470.38},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-2217-CG', 'total': 425354.89},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-2229-H', 'total': 507427.89},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-2243-H', 'total': 553400.7},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-2256-CG', 'total': 635920.92},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-2274-RR', 'total': 660634.14},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-2295-H', 'total': 356569.7},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-2296-H', 'total': 498798.0},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-2315-RR', 'total': 122358.14},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-2333-OG', 'total': 420909.32},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-2352-H', 'total': 469607.59},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-2386-OG ', 'total': 122554.14},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-4264-H', 'total': 309180.3},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-4526-H', 'total': 373464.52},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-5332-H', 'total': 308785.21},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-5631-RR', 'total': 918607.08},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-5661-H', 'total': 520641.83},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-6036-H', 'total': 811808.18},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-6397-H', 'total': 114036.55},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-6403-RR', 'total': 327200.87},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-6864-H', 'total': 169339.44},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-6910-H', 'total': 227308.7},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-6999-H', 'total': 376553.99},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-7034-H', 'total': 482660.73},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-7137-H', 'total': 256455.24},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-7214-RR', 'total': 373464.52},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-7348-RR', 'total': 215087.81},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-7349-RR', 'total': 120880.39},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-7350-RR', 'total': 120880.39},
#  {'dept': 'LAW', 'project': 'CA-D-LAW-7551-RR', 'total': 221414.92},
#  {'dept': 'MCB', 'project': 'CA-D-MCB-2310-H', 'total': 53294.96},
#  {'dept': 'MCB', 'project': 'CA-D-MCB-4126-H', 'total': 543605.77},
#  {'dept': 'MCB', 'project': 'CA-D-MCB-5554-H', 'total': 618483.22},
#  {'dept': 'MCB', 'project': 'CA-D-MCB-5896-H', 'total': 109084.6},
#  {'dept': 'MCB', 'project': 'CA-D-MCB-6239-H', 'total': 211795.51},
#  {'dept': 'MCB', 'project': 'CA-D-MCB-6365-H', 'total': 168706.63},
#  {'dept': 'MCB', 'project': 'CA-D-MCB-6471-H', 'total': 48556.64},
#  {'dept': 'MCB', 'project': 'CA-D-MCB-6731-H', 'total': 58146.64},
#  {'dept': 'MCB', 'project': 'CA-D-MCB-6735-H', 'total': 295257.33},
#  {'dept': 'MCB', 'project': 'CA-D-MCB-7165-H', 'total': 62918.16},
#  {'dept': 'MCB', 'project': 'CA-D-MCB-7237-H', 'total': 240170.78},
#  {'dept': 'MCB', 'project': 'CA-D-MCB-7399-H', 'total': 214952.25},
#  {'dept': 'MCB', 'project': 'CA-D-MCB-7420-H', 'total': 347008.31},
#  {'dept': 'MIC', 'project': 'CA-D-MMG-2313-H', 'total': 81518.49},
#  {'dept': 'MIC', 'project': 'CA-D-MMG-5733-H', 'total': 76769.34},
#  {'dept': 'MIC', 'project': 'CA-D-MMG-7235-H', 'total': 217780.93},
#  {'dept': 'MIC', 'project': 'CA-D-MMG-7402-H', 'total': 64986.84},
#  {'dept': 'MIC', 'project': 'CA-D-MMG-7473-H', 'total': 211160.9},
#  {'dept': 'NPB', 'project': 'CA-D-NPB-2330-H', 'total': 383187.29},
#  {'dept': 'NPB', 'project': 'CA-D-NPB-3512-H', 'total': 503868.4},
#  {'dept': 'NPB', 'project': 'CA-D-NPB-6309-H', 'total': 804803.98},
#  {'dept': 'NPB', 'project': 'CA-D-NPB-7153-H', 'total': 389995.0},
#  {'dept': 'NTR', 'project': 'CA-D-NTR-2060-H', 'total': 276147.45},
#  {'dept': 'NTR', 'project': 'CA-D-NTR-2092-H', 'total': 1637848.92},
#  {'dept': 'NTR', 'project': 'CA-D-NTR-2242-H', 'total': 340306.83},
#  {'dept': 'NTR', 'project': 'CA-D-NTR-2285-CG', 'total': 837141.47},
#  {'dept': 'NTR', 'project': 'CA-D-NTR-2407-CG', 'total': 255443.45},
#  {'dept': 'NTR', 'project': 'CA-D-NTR-4543-H', 'total': 1745304.75},
#  {'dept': 'NTR', 'project': 'CA-D-NTR-5908-H', 'total': 1648725.69},
#  {'dept': 'NTR', 'project': 'CA-D-NTR-5966-H', 'total': 503003.67},
#  {'dept': 'NTR', 'project': 'CA-D-NTR-6316-H', 'total': 2700298.97},
#  {'dept': 'NTR', 'project': 'CA-D-NTR-7836-H', 'total': 692505.85},
#  {'dept': 'PLB', 'project': 'CA-D-PLB-2259-H', 'total': 751667.86},
#  {'dept': 'PLB', 'project': 'CA-D-PLB-2260-H', 'total': 296373.15},
#  {'dept': 'PLB', 'project': 'CA-D-PLB-3504-H', 'total': 119312.55},
#  {'dept': 'PLB', 'project': 'CA-D-PLB-3511-CG', 'total': 327030.52},
#  {'dept': 'PLB', 'project': 'CA-D-PLB-3514-CG', 'total': 373991.52},
#  {'dept': 'PLB', 'project': 'CA-D-PLB-6167-H', 'total': 636835.15},
#  {'dept': 'PLB', 'project': 'CA-D-PLB-6991-H', 'total': 353546.17},
#  {'dept': 'PLB', 'project': 'CA-D-PLB-7226-H', 'total': 220838.99},
#  {'dept': 'PLB', 'project': 'CA-D-PLB-7381-H', 'total': 366547.81},
#  {'dept': 'PLB', 'project': 'CA-D-PLB-7412-H', 'total': 230911.52},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2013-H', 'total': 2260041.66},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2016-H', 'total': 952918.4},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2017-H', 'total': 279425.33},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2066-H', 'total': 1219983.83},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2073-H', 'total': 357603.83},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2078-H', 'total': 884739.72},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2079-H', 'total': 340808.54},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2125-CG', 'total': 1482012.44},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2127-CG', 'total': 683139.33},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2129-H', 'total': 850719.93},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2132-H', 'total': 406063.02},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2164-H', 'total': 229432.81},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2173-H', 'total': 233775.47},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2179-H', 'total': 1064739.62},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2183-H', 'total': 919012.02},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2205-H', 'total': 200617.29},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2218-OG', 'total': 329737.57},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2219-H', 'total': 339298.54},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2221-CG', 'total': 262918.18},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2222-CG', 'total': 263445.31},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2224-H', 'total': 724643.36},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2235-H', 'total': 279978.08},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2246-RR', 'total': 687222.01},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2247-H', 'total': 962770.72},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2272-OG', 'total': 212266.09},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2273-OG', 'total': 214788.7},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2276-OG', 'total': 273668.25},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2279-OG', 'total': 292535.3},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2289-OG', 'total': 236080.7},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2291-CG', 'total': 207636.7},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2305-CG', 'total': 196764.12},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2311-OG', 'total': 299355.7},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2324-OG', 'total': 187819.7},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2325-OG', 'total': 321920.18},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2327-H', 'total': 240858.96},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2329-OG', 'total': 304008.44},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2332-H', 'total': 579317.42},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2343-RR', 'total': 555935.26},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2349-H', 'total': 3112393.34},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2350-H', 'total': 515660.7},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2359-OG', 'total': 358947.08},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2370-CG', 'total': 217902.23},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2373-CG', 'total': 471580.44},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2378-OG', 'total': 168413.7},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2383-OG', 'total': 149728.7},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2384-OG', 'total': 234617.33},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2385-OG', 'total': 175370.32},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2418-CG', 'total': 149480.7},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-2424-CG', 'total': 140984.12},
#  {'dept': 'PLS', 'project': 'CA-D-PLS 5457-RR', 'total': 203897.48},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-5629-H', 'total': 750807.18},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-5884-H', 'total': 635037.43},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-5983-H', 'total': 265194.69},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-6063-H', 'total': 468454.17},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-6254-H', 'total': 477100.79},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-6273-H', 'total': 544197.05},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-6278-H', 'total': 2182727.25},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-6315-H', 'total': 445881.08},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-6410-H', 'total': 239504.76},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-6418-H', 'total': 1721644.84},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-6470-H', 'total': 372463.26},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-6599-H', 'total': 433037.44},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-6884-H', 'total': 2522314.11},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-7033-H', 'total': 512903.62},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-7121-H', 'total': 346040.87},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-7250-RR', 'total': 1428686.79},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-7259-RR', 'total': 671334.09},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-7262-RR', 'total': 750808.33},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-7279-H', 'total': 270638.48},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-7311-H', 'total': 720737.52},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-7344-H', 'total': 1147603.24},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-7514-RR', 'total': 508698.05},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-7641-H', 'total': 400080.02},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-7658-H', 'total': 188312.21},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-7663-RR', 'total': 454202.22},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-7680-H', 'total': 328837.88},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-7749-RR', 'total': 397349.42},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-7864-RR', 'total': 212473.21},
#  {'dept': 'PLS', 'project': 'CA-D-PLS-7869-H', 'total': 279986.97},
#  {'dept': 'PPA', 'project': 'CA-D-PPA-2021-H', 'total': 619532.47},
#  {'dept': 'PPA', 'project': 'CA-D-PPA-2022-H', 'total': 363585.5},
#  {'dept': 'PPA', 'project': 'CA-D-PPA-2025-H', 'total': 1297756.69},
#  {'dept': 'PPA', 'project': 'CA-D-PPA-2057-CG', 'total': 638410.19},
#  {'dept': 'PPA', 'project': 'CA-D-PPA-2131-H', 'total': 502529.82},
#  {'dept': 'PPA', 'project': 'CA-D-PPA-2165-H', 'total': 459112.75},
#  {'dept': 'PPA', 'project': 'CA-D-PPA-2167-OG', 'total': 450542.33},
#  {'dept': 'PPA', 'project': 'CA-D-PPA-2185-H', 'total': 460135.27},
#  {'dept': 'PPA', 'project': 'CA-D-PPA-2223-CG', 'total': 474221.5},
#  {'dept': 'PPA', 'project': 'CA-D-PPA-2226-CG', 'total': 207580.64},
#  {'dept': 'PPA', 'project': 'CA-D-PPA-2258-CG ', 'total': 480331.03},
#  {'dept': 'PPA', 'project': 'CA-D-PPA-2283-CG', 'total': 2319053.47},
#  {'dept': 'PPA', 'project': 'CA-D-PPA-2297-H', 'total': 517720.89},
#  {'dept': 'PPA', 'project': 'CA-D-PPA-2323-OG', 'total': 159950.01},
#  {'dept': 'PPA', 'project': 'CA-D-PPA-2347-OG', 'total': 878553.82},
#  {'dept': 'PPA', 'project': 'CA-D-PPA-2368-CG ', 'total': 157116.01},
#  {'dept': 'PPA', 'project': 'CA-D-PPA-2392-CG', 'total': 951423.07},
#  {'dept': 'PPA', 'project': 'CA-D-PPA-5484-H', 'total': 466994.23},
#  {'dept': 'PPA', 'project': 'CA-D-PPA-5681-H', 'total': 362829.03},
#  {'dept': 'PPA', 'project': 'CA-D-PPA-6395-H', 'total': 341577.33},
#  {'dept': 'PPA', 'project': 'CA-D-PPA-6456-H', 'total': 577440.2},
#  {'dept': 'PPA', 'project': 'CA-D-PPA-6575-H', 'total': 943877.07},
#  {'dept': 'PPA', 'project': 'CA-D-PPA-6699-H', 'total': 563534.4},
#  {'dept': 'PPA', 'project': 'CA-D-PPA-6738-H', 'total': 879834.09},
#  {'dept': 'PPA', 'project': 'CA-D-PPA-7268-RR', 'total': 362893.0},
#  {'dept': 'PPA', 'project': 'CA-D-PPA-7536-H', 'total': 2872991.03},
#  {'dept': 'PPA', 'project': 'CA-D-PPA-7629-RR', 'total': 504771.23},
#  {'dept': 'PPA', 'project': 'CA-D-PPA-7757-H', 'total': 438992.19},
#  {'dept': 'TXC', 'project': 'CA-D-TXC-4313-RR', 'total': 5505.0},
#  {'dept': 'TXC', 'project': 'CA-D-TXC-6424-RR', 'total': 99351.41},
#  {'dept': 'TXC', 'project': 'CA-D-TXC-6425-RR', 'total': 140790.13},
#  {'dept': 'TXC', 'project': 'CA-D-TXC-6706-H', 'total': 269785.77},
#  {'dept': 'TXC', 'project': 'CA-D-TXC-7694-H', 'total': 54781.41},
#  {'dept': 'TXC', 'project': 'CA-D-TXC-7739-H', 'total': 140783.81},
#  {'dept': 'VIT', 'project': 'CA-D-VIT-2196-H', 'total': 1171739.6},
#  {'dept': 'VIT', 'project': 'CA-D-VIT-2322-H', 'total': 458077.79},
#  {'dept': 'VIT', 'project': 'CA-D-VIT-2346-H', 'total': 446791.93},
#  {'dept': 'VIT', 'project': 'CA-D-VIT-4345-H', 'total': 500147.86},
#  {'dept': 'VIT', 'project': 'CA-D-VIT-4662-H', 'total': 441864.55},
#  {'dept': 'VIT', 'project': 'CA-D-VIT-6013-H', 'total': 427761.83},
#  {'dept': 'VIT', 'project': 'CA-D-VIT-6700-H', 'total': 237387.98},
#  {'dept': 'VIT', 'project': 'CA-D-VIT-6923-H', 'total': 677161.0},
#  {'dept': 'VIT', 'project': 'CA-D-VIT-7086-H', 'total': 2043091.92},
#  {'dept': 'VIT', 'project': 'CA-D-VIT-7120-H', 'total': 381555.51},
#  {'dept': 'VIT', 'project': 'CA-D-VIT-7727-H', 'total': 237387.98},
#  {'dept': 'VIT', 'project': 'CA-D-VIT-7728-H', 'total': 679212.16},
#  {'dept': 'VIT', 'project': 'CA-D-VIT-7729-H', 'total': 671245.8},
#  {'dept': 'WFB', 'project': 'CA-D-WFB-2097-H', 'total': 656373.95},
#  {'dept': 'WFB', 'project': 'CA-D-WFB-2098-H', 'total': 1628578.76},
#  {'dept': 'WFB', 'project': 'CA-D-WFB-2376-RR', 'total': 656373.95},
#  {'dept': 'WFB', 'project': 'CA-D-WFB-2381-OG', 'total': 606781.82},
#  {'dept': 'WFB', 'project': 'CA-D-WFB-4071-H', 'total': 740050.27},
#  {'dept': 'WFB', 'project': 'CA-D-WFB-5245-H', 'total': 701117.55},
#  {'dept': 'WFB', 'project': 'CA-D-WFB-6126-H', 'total': 732570.0},
#  {'dept': 'WFB', 'project': 'CA-D-WFB-6342-H', 'total': 980186.51},
#  {'dept': 'WFB', 'project': 'CA-D-WFB-6721-H', 'total': 529908.74}]

# %%
import json

with open('projectTotals.json', 'w') as fp:
    json.dump(data, fp)

# %%
# Now total up the departments

df_grouped = df.groupby('dept').agg('sum')

# %%
df_grouped.to_json('departmentTotals.json')

# %%
# Now spit out the departments to json

with open('departments.json', 'w') as fp:
    json.dump(departments, fp)

# %%
# get all projects and export by project number
project_df = pd.read_csv('./allprojects.csv')
project_df = project_df.fillna('')
project_df.head()
# Out:
#    AccessionNumber    ProjectNumber1  OrgR                     Department1  \
# 0            84385   CA-D-MCB-4126-H  BMCB  Molecular and Cellular Biology
# 1            87742   CA-D-EVE-4244-H  BEVE           Evolution and Ecology
# 2            88711   CA-D-ENM-4278-H  AENM       Entomology and Nematology
# 3            89754  CA-D-TXC-4313-RR  ATXC           Textiles and Clothing
# 4           134682   CA-D-FST-4929-H  AFST     Food Science and Technology
#
#   ProposalNumber AwardNumber  \
# 0
# 1
# 2
# 3
# 4
#
#                                                Title ProjectDirector  \
# 0          STRUCTURE FUNCTION STUDIES ON PHYTOCHROME    Lagarias,  J
# 1  Properties of Selection, Mutation and Drift in...     Turelli,  M
# 2  COMMUNICATION BETWEEN PLANTS AND INDUCED PLANT...      Karban,  R
# 3  Personal Protective Technologies for Current a...      Rucker,  M
# 4           CHEMISTRY OF LIPIDS IN FOODS AND TISSUES      German,  J
#
#   CoProjectDirectors      FundingSource ProjectStartDate ProjectEndDate  \
# 0                                 HATCH       10/01/2012     09/30/2017
# 1                                 HATCH       10/01/2012     09/30/2017
# 2                                 HATCH       10/01/2012     09/30/2017
# 3                     HATCH/MULTI-STATE       10/01/2012     09/30/2017
# 4                                 HATCH       10/01/2012     09/30/2017
#
#                    ProjectStatus  IsInterdepartmental  IsAssociable
# 0  Complete Without Final Report                False          True
# 1  Complete Without Final Report                False          True
# 2  Complete Without Final Report                False          True
# 3  Complete Without Final Report                False          True
# 4  Complete Without Final Report                False          True

# %%
project_data = {}

for index, row in project_df.iterrows():
    project_data[row['ProjectNumber1']] = { 
        'OrgR': row['OrgR'],
        'AccessionNumber': row['AccessionNumber'],
        'Title': row['Title'],
        'ProjectDirector': row['ProjectDirector'],
        'CoProjectDirectors': row['CoProjectDirectors'],
        'ProjectStartDate': row['ProjectStartDate'],
        'ProjectEndDate': row['ProjectEndDate']
    }

# %%
with open('projects.json', 'w') as fp:
    json.dump(project_data, fp)
